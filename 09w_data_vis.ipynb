# %% [markdown]
# <a href="https://colab.research.google.com/github/gong509/bda/blob/main/09w_data_vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# %config InlineBackend.figure_format = 'retina'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 65.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (5, 3)

# %%
plt.rcParams['figure.figsize']
# Out:
# [5.0, 3.0]

# %%
# !pip show pydataset
# Out:
# WARNING: Package(s) not found: pydataset

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 42.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=e671fd763c084ce4e1724a636c0d42825b80dc67b731bbfa48f6f1e01c0acf08
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# ...

# %%
from pydataset import data
tg = data('ToothGrowth')
tg.head()
# Out:
# initiated datasets repo at: /root/.pydataset/
#     len supp  dose
# 1   4.2   VC   0.5
# 2  11.5   VC   0.5
# 3   7.3   VC   0.5
# 4   5.8   VC   0.5
# 5   6.4   VC   0.5

# %%
tg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
tg.describe()
# Out:
#              len       dose
# count  60.000000  60.000000
# mean   18.813333   1.166667
# std     7.649315   0.628872
# min     4.200000   0.500000
# 25%    13.075000   0.500000
# 50%    19.250000   1.000000
# 75%    25.275000   2.000000
# max    33.900000   2.000000

# %%
import seaborn as sns
sns.boxplot(data=tg, x='dose', y='len', hue='supp')
plt.title('기니피그 치아 성장')
plt.xlabel('치아길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.stripplot(data=tg, x='dose', y='len', hue='supp', dodge=True)
plt.title('기니피그 치아 성장')
plt.xlabel('치아길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(data=tg, x='dose', y='len', hue='supp', dodge=True)
plt.title('기니피그 치아 성장')
plt.xlabel('치아길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()
