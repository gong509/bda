# %% [markdown]
# <a href="https://colab.research.google.com/github/gong509/bda/blob/main/06w_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

pf = pd.DataFrame(data = [[25, 35, 8, 18],
                          [18, 27, 10, 20],
                          [17, 17, 10, 19],
                          [12, 22, 9, 20],
                          [22, 34, 8, 16]],
  index=['윤일형', '강수희', '홍소희', '유한빈', '신수빈'],
  columns=['중간', '기말', '과제', '출석'])
pf
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  34   8  16

# %%
pf['중간']
# Out:
# 윤일형    25
# 강수희    18
# 홍소희    17
# 유한빈    12
# 신수빈    22
# Name: 중간, dtype: int64

# %%
pf.중간
# Out:
# 윤일형    25
# 강수희    18
# 홍소희    17
# 유한빈    12
# 신수빈    22
# Name: 중간, dtype: int64

# %%
pf['출석']
# Out:
# 윤일형    18
# 강수희    20
# 홍소희    19
# 유한빈    20
# 신수빈    16
# Name: 출석, dtype: int64

# %%
pf[['출석']]
# Out:
#      출석
# 윤일형  18
# 강수희  20
# 홍소희  19
# 유한빈  20
# 신수빈  16

# %%
pf[['기말', '출석', '중간']]
# Out:
#      기말  출석  중간
# 윤일형  35  18  25
# 강수희  27  20  18
# 홍소희  17  19  17
# 유한빈  22  20  12
# 신수빈  34  16  22

# %%
pf['중간'] > 20
# Out:
# 윤일형     True
# 강수희    False
# 홍소희    False
# 유한빈    False
# 신수빈     True
# Name: 중간, dtype: bool

# %%
pf[pf['중간'] > 20]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 신수빈  22  34   8  16

# %%
pf[pf['출석'] >= 19]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20

# %%
pf[(pf['출석'] >= 19) & (pf['기말'] >= 20)]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 유한빈  12  22   9  20

# %%
pf.loc['윤일형']
# Out:
# 중간    25
# 기말    35
# 과제     8
# 출석    18
# Name: 윤일형, dtype: int64

# %%
pf.loc[['윤일형']]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18

# %%
pf.loc[['홍소희', '윤일형']]
# Out:
#      중간  기말  과제  출석
# 홍소희  17  17  10  19
# 윤일형  25  35   8  18

# %%
pf.loc['윤일형':'유한빈']
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20

# %%
pf.loc[pf.중간 > 20]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 신수빈  22  34   8  16

# %%
pf.loc[(pf.중간 > 10) & (pf.과제 == 10)]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 홍소희  17  17  10  19

# %%
pf.loc[pf.index[0]] # 첫 번째 행 검색
# Out:
# 중간    25
# 기말    35
# 과제     8
# 출석    18
# Name: 윤일형, dtype: int64

# %%
pf.loc[[pf.index[0]]] # 첫 번째 행 검색
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18

# %%
pf.loc[pf.index[1:4]] # 슬라이싱 행 검색
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20

# %%
pf.loc[pf.index[1:4]][['기말', '과제']]
# Out:
#      기말  과제
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9

# %%
pf.loc[:,'과제']
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf.loc[:, '중간':'과제']
# Out:
#      중간  기말  과제
# 윤일형  25  35   8
# 강수희  18  27  10
# 홍소희  17  17  10
# 유한빈  12  22   9
# 신수빈  22  34   8

# %%
pf.loc[:, ['기말', '출석']]
# Out:
#      기말  출석
# 윤일형  35  18
# 강수희  27  20
# 홍소희  17  19
# 유한빈  22  20
# 신수빈  34  16

# %%
pf.loc[:, pf.columns[0]]
# Out:
# 윤일형    25
# 강수희    18
# 홍소희    17
# 유한빈    12
# 신수빈    22
# Name: 중간, dtype: int64

# %%
pf.loc[:, [pf.columns[0]]]
# Out:
#      중간
# 윤일형  25
# 강수희  18
# 홍소희  17
# 유한빈  12
# 신수빈  22

# %%
pf.loc[:, pf.columns[1:]]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.loc[:, pf.columns[1:3]]
# Out:
#      기말  과제
# 윤일형  35   8
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9
# 신수빈  34   8

# %%
pf.loc[:, pf.columns[1:]]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.loc['윤일형', '출석']
# Out:
# np.int64(18)

# %%
pf.loc['윤일형':'유한빈', '기말']
# Out:
# 윤일형    35
# 강수희    27
# 홍소희    17
# 유한빈    22
# Name: 기말, dtype: int64

# %%
pf.loc['윤일형':'유한빈', '기말':'과제']
# Out:
#      기말  과제
# 윤일형  35   8
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9

# %%
pf.loc[pf.index[0], pf.columns[1]]
# Out:
# np.int64(35)

# %%
pf.loc[pf.index[0:3], pf.columns[2]]
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# Name: 과제, dtype: int64

# %%
pf.loc[pf.index[0:3], pf.columns[2:]]
# Out:
#      과제  출석
# 윤일형   8  18
# 강수희  10  20
# 홍소희  10  19

# %%
pf.iloc[1]
# Out:
# 중간    18
# 기말    27
# 과제    10
# 출석    20
# Name: 강수희, dtype: int64

# %%
pf.iloc[[1]]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20

# %%
pf.iloc[[1, 3]]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 유한빈  12  22   9  20

# %%
pf.iloc[2:]
# Out:
#      중간  기말  과제  출석
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  34   8  16

# %%
pf.iloc[:, 2]
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf.iloc[:, [2]]
# Out:
#      과제
# 윤일형   8
# 강수희  10
# 홍소희  10
# 유한빈   9
# 신수빈   8

# %%
pf.iloc[:, 1:]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.iloc[1, 1]
# Out:
# np.int64(27)

# %%
pf.iloc[1:3, 1:]
# Out:
#      기말  과제  출석
# 강수희  27  10  20
# 홍소희  17  10  19

# %%
pf.iloc[:, 1:]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.iloc[[1, 3, 4], 1:]
# Out:
#      기말  과제  출석
# 강수희  27  10  20
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.iloc[[1, 3, 4], [0, 1]]
# Out:
#      중간  기말
# 강수희  18  27
# 유한빈  12  22
# 신수빈  22  34

# %%
pf.at['윤일형', '과제']
# Out:
# np.int64(8)

# %%
pf.at['유한빈', '기말']
# Out:
# np.int64(22)

# %%
pf.at[pf.index[1], '출석']
# Out:
# np.int64(20)

# %%
pf.at[pf.index[3], pf.columns[2]]
# Out:
# np.int64(9)

# %%
pf.iat[1, 2]
# Out:
# np.int64(10)

# %%
pf.iat[2, 3]
# Out:
# np.int64(19)

# %%
import pandas as pd

df = pd.read_csv('2016년졸음운전.csv',
                 encoding='euc-kr', index_col=0)
df
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# 2016년7월     227      9    460
# 2016년8월     230      7    490
# 2016년9월     187     13    347
# 2016년10월    183     10    367
# 2016년11월    200      5    418
# 2016년12월    168      4    364

# %%
df.dtypes
# Out:
# 사고(건)    int64
# 사망(명)    int64
# 부상(명)    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2016년1월 to 2016년12월
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사고(건)   12 non-null     int64
#  1   사망(명)   12 non-null     int64
#  2   부상(명)   12 non-null     int64
# dtypes: int64(3)
# memory usage: 384.0+ bytes

# %%
df.describe()
# Out:
#             사고(건)      사망(명)       부상(명)
# count   12.000000  12.000000   12.000000
# mean   202.750000   8.166667  408.250000
# std     23.014324   3.186144   60.051682
# min    168.000000   4.000000  328.000000
# 25%    186.000000   5.750000  363.500000
# 50%    200.000000   7.000000  402.500000
# 75%    219.500000  10.500000  441.250000
# max    239.000000  13.000000  522.000000

# %%
df.T
# Out:
# 연월     2016년1월  2016년2월  2016년3월  2016년4월  2016년5월  2016년6월  2016년7월  2016년8월  \
# 사고(건)      192      174      217      216      239      200      227      230
# 사망(명)        5        6        7        7       13       12        9        7
# 부상(명)      387      328      435      419      522      362      460      490
#
# 연월     2016년9월  2016년10월  2016년11월  2016년12월
# 사고(건)      187       183       200       168
# 사망(명)       13        10         5         4
# 부상(명)      347       367       418       364

# %%
df.sum()
# Out:
# 사고(건)    2433
# 사망(명)      98
# 부상(명)    4899
# dtype: int64

# %%
df.sum(axis=0)
# Out:
# 사고(건)    2433
# 사망(명)      98
# 부상(명)    4899
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 연월
# 2016년1월     584
# 2016년2월     508
# 2016년3월     659
# 2016년4월     642
# 2016년5월     774
# 2016년6월     574
# 2016년7월     696
# 2016년8월     727
# 2016년9월     547
# 2016년10월    560
# 2016년11월    623
# 2016년12월    536
# dtype: int64

# %%
df.cumsum(axis=0)
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월     192      5    387
# 2016년2월     366     11    715
# 2016년3월     583     18   1150
# 2016년4월     799     25   1569
# 2016년5월    1038     38   2091
# 2016년6월    1238     50   2453
# 2016년7월    1465     59   2913
# 2016년8월    1695     66   3403
# 2016년9월    1882     79   3750
# 2016년10월   2065     89   4117
# 2016년11월   2265     94   4535
# 2016년12월   2433     98   4899

# %%
df.cumsum(axis=1)
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월     192    197    584
# 2016년2월     174    180    508
# 2016년3월     217    224    659
# 2016년4월     216    223    642
# 2016년5월     239    252    774
# 2016년6월     200    212    574
# 2016년7월     227    236    696
# 2016년8월     230    237    727
# 2016년9월     187    200    547
# 2016년10월    183    193    560
# 2016년11월    200    205    623
# 2016년12월    168    172    536

# %%
df.mean()
# Out:
# 사고(건)    202.750000
# 사망(명)      8.166667
# 부상(명)    408.250000
# dtype: float64

# %%
df.mean()
# Out:
# 사고(건)    202.750000
# 사망(명)      8.166667
# 부상(명)    408.250000
# dtype: float64

# %%
df.mean(axis=0)
# Out:
# 사고(건)    202.750000
# 사망(명)      8.166667
# 부상(명)    408.250000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 연월
# 2016년1월     194.666667
# 2016년2월     169.333333
# 2016년3월     219.666667
# 2016년4월     214.000000
# 2016년5월     258.000000
# 2016년6월     191.333333
# 2016년7월     232.000000
# 2016년8월     242.333333
# 2016년9월     182.333333
# 2016년10월    186.666667
# 2016년11월    207.666667
# 2016년12월    178.666667
# dtype: float64

# %%
df.mean(axis=None)
# Out:
# np.float64(206.38888888888889)

# %%
df.max()
# Out:
# 사고(건)    239
# 사망(명)     13
# 부상(명)    522
# dtype: int64

# %%
df.max(axis=0)
# Out:
# 사고(건)    239
# 사망(명)     13
# 부상(명)    522
# dtype: int64

# %%
df.max(axis=0)
# Out:
# 사고(건)    239
# 사망(명)     13
# 부상(명)    522
# dtype: int64

# %%
df.max(axis=1)
# Out:
# 연월
# 2016년1월     387
# 2016년2월     328
# 2016년3월     435
# 2016년4월     419
# 2016년5월     522
# 2016년6월     362
# 2016년7월     460
# 2016년8월     490
# 2016년9월     347
# 2016년10월    367
# 2016년11월    418
# 2016년12월    364
# dtype: int64

# %%
df.min()
# Out:
# 사고(건)    168
# 사망(명)      4
# 부상(명)    328
# dtype: int64

# %%
df.min(axis=0)
# Out:
# 사고(건)    168
# 사망(명)      4
# 부상(명)    328
# dtype: int64

# %%
df.min(axis=1)
# Out:
# 연월
# 2016년1월      5
# 2016년2월      6
# 2016년3월      7
# 2016년4월      7
# 2016년5월     13
# 2016년6월     12
# 2016년7월      9
# 2016년8월      7
# 2016년9월     13
# 2016년10월    10
# 2016년11월     5
# 2016년12월     4
# dtype: int64

# %%
df.max(axis=None)
# Out:
# 522

# %%
df.min=(axis=None)
# Out:
#   File "/tmp/ipykernel_730/2717892475.py", line 1
#     df.min=(axis=None)
#             ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df[['사망(명)', '부상(명)']].sum(axis=1)
# Out:
# 연월
# 2016년1월     392
# 2016년2월     334
# 2016년3월     442
# 2016년4월     426
# 2016년5월     535
# 2016년6월     374
# 2016년7월     469
# 2016년8월     497
# 2016년9월     360
# 2016년10월    377
# 2016년11월    423
# 2016년12월    368
# dtype: int64

# %%
df.iloc[:, 1:].sum(axis=1)
# Out:
# 연월
# 2016년1월     392
# 2016년2월     334
# 2016년3월     442
# 2016년4월     426
# 2016년5월     535
# 2016년6월     374
# 2016년7월     469
# 2016년8월     497
# 2016년9월     360
# 2016년10월    377
# 2016년11월    423
# 2016년12월    368
# dtype: int64

# %%
df2 = df.copy()
df2['재해자수'] = df[['사망(명)','부상(명)']].sum(axis=1)
df2
# Out:
#           사고(건)  사망(명)  부상(명)  재해자수
# 연월
# 2016년1월     192      5    387   392
# 2016년2월     174      6    328   334
# 2016년3월     217      7    435   442
# 2016년4월     216      7    419   426
# 2016년5월     239     13    522   535
# 2016년6월     200     12    362   374
# 2016년7월     227      9    460   469
# 2016년8월     230      7    490   497
# 2016년9월     187     13    347   360
# 2016년10월    183     10    367   377
# 2016년11월    200      5    418   423
# 2016년12월    168      4    364   368

# %%
df2.sum()
# Out:
# 사고(건)    2433
# 사망(명)      98
# 부상(명)    4899
# 재해자수     4997
# dtype: int64

# %%
df2.loc['총계'] = df2.sum(axis=0)
df2
# Out:
#           사고(건)  사망(명)  부상(명)  재해자수
# 연월
# 2016년1월     192      5    387   392
# 2016년2월     174      6    328   334
# 2016년3월     217      7    435   442
# 2016년4월     216      7    419   426
# 2016년5월     239     13    522   535
# 2016년6월     200     12    362   374
# 2016년7월     227      9    460   469
# 2016년8월     230      7    490   497
# 2016년9월     187     13    347   360
# 2016년10월    183     10    367   377
# 2016년11월    200      5    418   423
# 2016년12월    168      4    364   368
# 총계         2433     98   4899  4997

# %%
df2 > 10
# Out:
#           사고(건)  사망(명)  부상(명)  재해자수
# 연월
# 2016년1월    True  False   True  True
# 2016년2월    True  False   True  True
# 2016년3월    True  False   True  True
# 2016년4월    True  False   True  True
# 2016년5월    True   True   True  True
# 2016년6월    True   True   True  True
# 2016년7월    True  False   True  True
# 2016년8월    True  False   True  True
# 2016년9월    True   True   True  True
# 2016년10월   True  False   True  True
# 2016년11월   True  False   True  True
# 2016년12월   True  False   True  True
# 총계         True   True   True  True

# %%
df2[df2 > 10]
# Out:
#           사고(건)  사망(명)  부상(명)  재해자수
# 연월
# 2016년1월     192    NaN    387   392
# 2016년2월     174    NaN    328   334
# 2016년3월     217    NaN    435   442
# 2016년4월     216    NaN    419   426
# 2016년5월     239   13.0    522   535
# 2016년6월     200   12.0    362   374
# 2016년7월     227    NaN    460   469
# 2016년8월     230    NaN    490   497
# 2016년9월     187   13.0    347   360
# 2016년10월    183    NaN    367   377
# 2016년11월    200    NaN    418   423
# 2016년12월    168    NaN    364   368
# 총계         2433   98.0   4899  4997

# %%
df2[ [True]*6 + [False]*7]
# Out:
#          사고(건)  사망(명)  부상(명)  재해자수
# 연월
# 2016년1월    192      5    387   392
# 2016년2월    174      6    328   334
# 2016년3월    217      7    435   442
# 2016년4월    216      7    419   426
# 2016년5월    239     13    522   535
# 2016년6월    200     12    362   374

# %%
df2['재해자수'] > 400
# Out:
# 연월
# 2016년1월     False
# 2016년2월     False
# 2016년3월      True
# 2016년4월      True
# 2016년5월      True
# 2016년6월     False
# 2016년7월      True
# 2016년8월      True
# 2016년9월     False
# 2016년10월    False
# 2016년11월     True
# 2016년12월    False
# 총계           True
# Name: 재해자수, dtype: bool

# %%
df['사망(명)'] == 7
# Out:
# 연월
# 2016년1월     False
# 2016년2월     False
# 2016년3월      True
# 2016년4월      True
# 2016년5월     False
# 2016년6월     False
# 2016년7월     False
# 2016년8월      True
# 2016년9월     False
# 2016년10월    False
# 2016년11월    False
# 2016년12월    False
# Name: 사망(명), dtype: bool

# %%
df2[df2['재해자수'] > 400]
# Out:
#           사고(건)  사망(명)  부상(명)  재해자수
# 연월
# 2016년3월     217      7    435   442
# 2016년4월     216      7    419   426
# 2016년5월     239     13    522   535
# 2016년7월     227      9    460   469
# 2016년8월     230      7    490   497
# 2016년11월    200      5    418   423
# 총계         2433     98   4899  4997

# %%
df['사망(명)'].isin([7])
# Out:
# 연월
# 2016년1월     False
# 2016년2월     False
# 2016년3월      True
# 2016년4월      True
# 2016년5월     False
# 2016년6월     False
# 2016년7월     False
# 2016년8월      True
# 2016년9월     False
# 2016년10월    False
# 2016년11월    False
# 2016년12월    False
# Name: 사망(명), dtype: bool

# %%
df['사망(명)'].isin([7, 10])
# Out:
# 연월
# 2016년1월     False
# 2016년2월     False
# 2016년3월      True
# 2016년4월      True
# 2016년5월     False
# 2016년6월     False
# 2016년7월     False
# 2016년8월      True
# 2016년9월     False
# 2016년10월     True
# 2016년11월    False
# 2016년12월    False
# Name: 사망(명), dtype: bool

# %%
df[df['사망(명)'].isin([7, 10])]
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년8월     230      7    490
# 2016년10월    183     10    367

# %%
df[(df['사망(명)'].isin([7, 10])) | (df['부상(명)'] > 350)]
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월     192      5    387
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# 2016년7월     227      9    460
# 2016년8월     230      7    490
# 2016년10월    183     10    367
# 2016년11월    200      5    418
# 2016년12월    168      4    364

# %%
df[df.index.str.contains('3')]
# Out:
#          사고(건)  사망(명)  부상(명)
# 연월
# 2016년3월    217      7    435

# %%
df3 = df.copy()
df3
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# 2016년7월     227      9    460
# 2016년8월     230      7    490
# 2016년9월     187     13    347
# 2016년10월    183     10    367
# 2016년11월    200      5    418
# 2016년12월    168      4    364

# %%
df3[df3 > 10] = -df3
df3
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월    -192      5   -387
# 2016년2월    -174      6   -328
# 2016년3월    -217      7   -435
# 2016년4월    -216      7   -419
# 2016년5월    -239    -13   -522
# 2016년6월    -200    -12   -362
# 2016년7월    -227      9   -460
# 2016년8월    -230      7   -490
# 2016년9월    -187    -13   -347
# 2016년10월   -183     10   -367
# 2016년11월   -200      5   -418
# 2016년12월   -168      4   -364

# %%
df = pd.DataFrame({'A': range(1, 6),
                   'B': range(6, -3, -2),
                   'C': range(10, 5, -1),
                   'D clmns': range(3, -2, -1),
                   'E': ['python', 'java', 'python', 'go', 'python']})
df
# Out:
#    A  B   C  D clmns       E
# 0  1  6  10        3  python
# 1  2  4   9        2    java
# 2  3  2   8        1  python
# 3  4  0   7        0      go
# 4  5 -2   6       -1  python

# %%
df.query('c == 10')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.12/collections/__init__.py in __getitem__(self, key)
#    1014                 pass
# -> 1015         return self.__missing__(key)            # support subclasses that define __missing__
#    1016
#
# /usr/lib/python3.12/collections/__init__.py in __missing__(self, key)
#    1006     def __missing__(self, key):
# -> 1007         raise KeyError(key)
#    1008
#
# KeyError: 'c'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.query('A > 0')
# Out:
#    A  B   C  D clmns       E
# 0  1  6  10        3  python
# 1  2  4   9        2    java
# 2  3  2   8        1  python
# 3  4  0   7        0      go
# 4  5 -2   6       -1  python

# %%
df.query('E == "python"')
# Out:
#    A  B   C  D clmns       E
# 0  1  6  10        3  python
# 2  3  2   8        1  python
# 4  5 -2   6       -1  python

# %%
df.query("E != 'python'")
# Out:
#    A  B  C  D clmns     E
# 1  2  4  9        2  java
# 3  4  0  7        0    go

# %%
df.query('A ==')
